# %%
#1
#sum of first 10 natural numbers
sum=0
for i in range(1,11):
  sum+=i
print(sum)
# Out:
# 55

# %%
#2
#find the factorial of a number
n=int(input("enter a number : "))
fact=1
for i in range(1,n+1):
  fact = fact*i
print(fact)
# Out:
# enter a number : 4
# 24

# %%
#3
#print fibonacci sequence
n=int(input("enter the number of terms: "))
a,b=0,1
print("fibonacci sequence is :")
for i in range(n):
  print(a, end=" ")
  a,b=b,a+b
# Out:
# enter the number of terms: 5
# fibonacci sequence is :
# 0 1 1 2 3

# %%
#4
#find largest among three numbers
nums=[22,44,54]
largest=nums[0]
for i in nums:
   if i > largest:
    largest=i
print("largest : ",i)
# Out:
# largest :  54

# %%
#5
#student result system
#input student details
name= input("enter name: ")
roll_no=int(input("enter roll number: "))
age=int(input("enter age: "))
math=float(input("Enter marks scored in maths out of 100 : "))
phy=float(input("Enter marks scored in phy out of 100: "))
chem=float(input("Enter marks scored in chem out of 100: "))
total_marksscored=math + phy + chem
percentage= (total_marksscored/300)*100
print(percentage)
if percentage >= 91:
  print("GRADE A")
if 80< percentage <=90:
  print("GRADE B")
if 70< percentage <=80:
  print("GRADE C")
if percentage<=70:
  print("GRADE D")
# Out:
# enter name: aman
# enter roll number: 88
# enter age: 22
# Enter marks scored in maths out of 100 : 22
# Enter marks scored in phy out of 100: 90
# Enter marks scored in chem out of 100: 99
# 70.33333333333334
# GRADE C
